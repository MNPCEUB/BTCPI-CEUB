# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Problema: Calcular o valor total da compra de um produto.
# 2. Algoritmo:
# Passo 1: Receba o código do produto
# Passo 2: Receba o valor do produto
# Passo 3: Receba quantidade de produto
#
# Passo 4: Calcule o valor total da compra valor do produto X quantidade de produto)
#
# Passo 5: Mostre o código do produto e seu valor total da compra
#
# 3. Identifique no algoritmo acima: as entradas, o processamento e a saída

# %%
codigo = float(input(' digite o codigo do produto'))
valor = float(input(' digite o valor do produto'))
qnto = float(input(' digite o numero de produtos'))
total = (valor*qnto)

print(codigo, total)
# Out:
#  digite o codigo do produto10
#  digite o valor do produto2
#  digite o numero de produtos3
# 10.0 6.0

# %% [markdown]
# 1. Problema:Calcular a média aritmética final de um aluno. O aluno realizou quatro avaliações: A1, A2, A3 e A4.
#
# 2. Responda:
# Quais são os dados de entrada?
#
# Qual é o processamento?
#
# Qual o dado de saída?
#
#
# 3. No próximo slide:Desenvolva o algoritmo para resolver esse problema

# %%
av1 = float(input(' digite a sua primeira nota'))
av2 = float(input(' digite a sua segunda nota'))
av3 = float(input(' digite a sua terceira nota'))
av4 = float(input(' digite a sua quarta nota'))

media_final=(av1+av2+av3+av4)/4
if media_final>=5:
  print(media_final)
  print('aprovado')
else:
  print(media_final)
  print('reprovado')

# %% [markdown]
# Algoritmo para monitorar a febre de um paciente:
#
# Verifique a temperatura
#
# Enquanto a temperatura não for febre:
#
# Aguarde trinta minutos
# Verifique a temperatura novamente
#
# Ative o alarme de febre

# %%
temp = float(input('qual sua temperatura atual?'))
print(temp)
if temp<37.5:
  print('normal')
  print('cheque novamente em 30 minutos')
else:
  print('febre')
  print('ativar alarme')
# Out:
# qual sua temperatura atual?38
# 38.0
# febre
# ativar alarme

# %% [markdown]
# Faca um algoritmo para receber dois números e somar os dois números.
#
# Multiplique o resultado da soma pelo primeiro número e exiba o resultado da multiplicação em tela.

# %%
num1 = int(input('digite um numero'))
num2 = int(input('digite um outro numero'))

total1 = num1+num2
total2 = num1*total1
print(total2)

# %% [markdown]
# how to identify class

# %%
x = 3.0
type(x), print(type(x))

y = 3j
type(y), print(type(y))

z = 3
type(z), print(type(z))

c = 3 > 4
type(c), print(type(c))
# Out:
# <class 'float'>
# <class 'complex'>
# <class 'int'>
# <class 'bool'>
# (bool, None)

# %% [markdown]
# Use o operador resto de divisão ( % ):
#
#
# Verifique se x % y é igual a zero.
#
# Ou seja, verifique se o resto da divisão de x por y é igual a zero.

# %%
c = 7/6
z = 7%6
print(c)
if c==0:
  print('true')
else:
  print('false')
  print(z)

# %% [markdown]
# Observe o programa abaixo e calcule, com o auxilio de lápis e papel, quais resultados serão impressos. Depois execute o programa no IDE e verifique se você acertou.
#
# x = 45
#
# y = 14
#
# z = x // y			- Respostas dos prints:
#
# print(z)
# 3
#
# z = y % z
#
# print(x)
# 45
#
# y = 10
#
# print(z)
# 2

# %%
x = 45

y = 14

z = x // y
print(z)
z = y % z
y = 10
print(z)
# Out:
# 3
# 2

# %% [markdown]
# Formatação, usa-se {} como "placeholder" para as variaveis que voce colocara apos o .format, como no exemplo abaixo

# %%
x = 14
y = 3
print(x, '//', y, '=', x//y)
# ou
print('{} // {} = {}'.format(x, y, x//y))
# Out:
# 14 // 3 = 4
# 14 // 3 = 4

# %% [markdown]
# Problema:
# Projete o programa que leia um valor numérico e verifique se ele é maior ou igual a cem. Mostre uma das mensagens: "Valor maior ou igual a cem." ου "Valor menor que cem."
#
# Analise o problema e verifique quais são os dados que o usuário precisa fornecer (digitar) como entrada.
#
# Passos para a resolução do problema (algoritmo):
#
# Entrada de dados (leia)
#
# Teste 1: Entrada: valor 200
# Saída: Valor maior ou igual a cem.
#
# Teste 2: Entrada: valor = 20
# Saida: Valor menor que cem.
#
# Teste 3: Entrada: valor = 100
# Saida: Valor maior ou igual a cem.

# %%
valor = int(input('digite um valor'))
print(valor)
if valor >= 100:
  print('seu numero é maior ou igual a cem')
else:
  print('seu numero é menor que cem')
# Out:
# digite um valor123
# 123
# seu numero é maior ou igual a cem

# %%
valor = int(input('digite um valor'))
if valor/2 == isinstance(int):
  print('seu valor é par')
else:
  print('seu valor é impar')
# Out:
# digite um valor5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-288ee0ac6368> in <cell line: 0>()
#       1 valor = int(input('digite um valor'))
# ----> 2 if valor/2 == isinstance(int):
#       3   print('seu valor é par')
#       4 else:
#       5   print('seu valor é impar')
#
# TypeError: isinstance expected 2 arguments, got 1

# %%
type(1.5)
# Out:
# float

# %%
valor = int(input('digite um valor'))
if valor%2 == par:
  print('seu valor é par')
else:
  print('seu valor é impar')
# Out:
# digite um valor1
# impar

# %%
valor = int(input("anblka: "))
valor = valor/2
valor2 = valor - int(valor)
if valor2 * 10 == 0:
  print("par")
  print(valor2)
else:
  print("impar")
  print(valor2)
# Out:
# anblka:14
# par
# 0.0

# %%
number = 10
print(isinstance(number, int))
# Out:
# True

# %%
senha = int(input('digite sua senha'))
if senha == 123:
  print('senha correta')
else:
  print('senha incorreta')
# Out:
# digite sua senha123
# senha correta

# %%
senha = input('digite sua senha')
if senha == '2b3':
  print('senha correta')
else:
  print('senha incorreta')
# Out:
# digite sua senha2b5
# senha incorreta
